# %%
#ID_settings
# import required libraries and settings
import pandas as pd
import glob
import numpy as np
import csv
import openai
import random
import re
import time 
import matplotlib.pyplot as plt
from tqdm import tqdm
import ipywidgets as widgets
from IPython.display import display


# Create the 'TVDL' dropdown menu with options
TT = widgets.Dropdown(
    options=['1', '3','5'],
    value='1',
    description='Test Time'
)

# Create the 'prompt' dropdown menu with options
prompt_dropdown = widgets.Dropdown(
    options=['None 0', 'None 1', 'None 2', 'Generic 0','Generic 1','Generic 2', 'Specific 0', 'Specific 1', 'Specific 2'],
    value='None 0',
    description='Prompt:'
)


# Create the 'Model' dropdown menu with options
model_dropdown = widgets.Dropdown(
    options=['gpt-3.5-turbo', 'gpt-4-1106-preview'],
    value='gpt-3.5-turbo',
    description='Model:'
)

# Create NumberBoxes for 'Number of Development' and 'Number of Experiments'
num_development = widgets.IntText(
    value=10,
    description='Dev. Cycle:',
    layout={'width': 'auto'}
)

num_experiments = widgets.IntText(
    value=5,
    description='Experiments:',
    layout={'width': 'auto'}
)

# Create a TextBox for 'Model-Temperatures'
model_temperatures = widgets.Text(
    value='0',
    description='Temperature Setting:',
    layout={'width': 'auto'}
)

# Create the FloatSlider for 'Target' as a percentage
targ_quant = widgets.FloatSlider(
    value=99,
    min=50,
    max=100,
    step=1,
    description='Target:',
    layout={'width': 'auto'}
)

conversation_dropdown = widgets.Dropdown(
    options=['Complete', 'Exceptions+Results'],
    value='Exceptions+Results',
    description='Display Conversation:'
)

# Arrange the widgets in two columns
left_column = widgets.VBox([model_dropdown, num_development, num_experiments, conversation_dropdown])
right_column = widgets.VBox([prompt_dropdown, model_temperatures,targ_quant, TT])

# Create an overall layout with two columns
main_layout = widgets.HBox([left_column, right_column])
title = widgets.HTML("<h2>Settings of Inverse Design Experiments</h2>")
settings = widgets.VBox([title, main_layout])
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget_selection.py:133, in findvalue(array, value, compare)
#     132 try:
# --> 133     return next(x for x in array if compare(x, value))
#     134 except StopIteration:
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget_selection.py:242, in _Selection._validate_value(self, proposal)
#     241 try:
# --> 242     return findvalue(self._options_values, value, self.equals) if value is not None else None
#     243 except ValueError:
#
# File ~/anaconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget_selection.py:135, in findvalue(array, value, compare)
#     134 except StopIteration:
# --> 135     raise ValueError('%r not in array'%value)
#
# ValueError: 'Off' not in array
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# Cell In[2], line 32
#      25 prompt_dropdown = widgets.Dropdown(
#      26     options=['None 0', 'None 1', 'None 2', 'Generic 0','Generic 1','Generic 2', 'Specific 0', 'Specific 1', 'Specific 2'],
#      27     value='None 0',
#      28     description='Prompt:'
#      29 )
#      31 # Create the 'prompt' dropdown menu with options
# ---> 32 gen_VM = widgets.Dropdown(
#      33     options=['o','Generic 0','Generic 1','Generic 2'],
#      34     value='Off',
#      35     description='VM Knowledge:'
#      36 )
#      38 # Create the 'Model' dropdown menu with options
#      39 model_dropdown = widgets.Dropdown(
#      40     options=['gpt-3.5-turbo', 'gpt-4-1106-preview'],
#      41     value='gpt-3.5-turbo',
#      42     description='Model:'
#      43 )
#
# File ~/anaconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget_selection.py:186, in _Selection.__init__(self, *args, **kwargs)
#     183     kwargs['index'] = 0 if nonempty else None
#     184     kwargs['label'], kwargs['value'] = options[0] if nonempty else (None, None)
# --> 186 super().__init__(*args, **kwargs)
#     187 self._initializing_traits_ = False
#
# File ~/anaconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget_description.py:35, in DescriptionWidget.__init__(self, *args, **kwargs)
#      33     kwargs.setdefault('tooltip', kwargs['description_tooltip'])
#      34     del kwargs['description_tooltip']
# ---> 35 super().__init__(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:502, in Widget.__init__(self, **kwargs)
#     500 """Public constructor"""
#     501 self._model_id = kwargs.pop('model_id', None)
# --> 502 super().__init__(**kwargs)
#     504 Widget._call_widget_constructed(self)
#     505 self.open()
#
# File ~/anaconda3/lib/python3.11/site-packages/traitlets/traitlets.py:1357, in HasTraits.__init__(self, *args, **kwargs)
#    1355 changed = set(kwargs) & set(self._traits)
#    1356 for key in changed:
# -> 1357     value = self._traits[key]._cross_validate(self, getattr(self, key))
#    1358     self.set_trait(key, value)
#    1359     changes[key]['new'] = value
#
# File ~/anaconda3/lib/python3.11/site-packages/traitlets/traitlets.py:743, in TraitType._cross_validate(self, obj, value)
#     741 if self.name in obj._trait_validators:
#     742     proposal = Bunch({"trait": self, "value": value, "owner": obj})
# --> 743     value = obj._trait_validators[self.name](obj, proposal)
#     744 elif hasattr(obj, "_%s_validate" % self.name):
#     745     meth_name = "_%s_validate" % self.name
#
# File ~/anaconda3/lib/python3.11/site-packages/traitlets/traitlets.py:1229, in EventHandler.__call__(self, *args, **kwargs)
#    1227 """Pass `*args` and `**kwargs` to the handler's function if it exists."""
#    1228 if hasattr(self, "func"):
# -> 1229     return self.func(*args, **kwargs)
#    1230 else:
#    1231     return self._init_call(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget_selection.py:244, in _Selection._validate_value(self, proposal)
#     242     return findvalue(self._options_values, value, self.equals) if value is not None else None
#     243 except ValueError:
# --> 244     raise TraitError('Invalid selection: value not found')
#
# TraitError: Invalid selection: value not found
