# %% [markdown]
# ## Usage Guidelines for this Jupyter Notebook
#
# ### Important Precautions
#
# - **Unsupervised Execution**: Avoid running this notebook unsupervised. Despite our efforts to develop robust code, it may occasionally get stuck in an infinite loop, where each iteration can incur costs.
# - **GPT-4 Model**: Exercise caution when using the GPT-4 model due to its high expense.
# - **Cell Execution**: Execute each cell individually and sequentially to ensure settings from the previous cell are correctly passed to the subsequent one.
# - **Save Prompts**: Make sure to click the save button if you have changed the prompts. This will overwrite your previous prompts.
#
#
# ### Usage Instructions
#
# - **Dependencies**: This notebook relies on  `Settings`, `Utilities`, `Run_Experiments`, and `Run_Baselines` notebooks from the `the utils/` subfolder.
# - **Result Analysis**: This notebook only generates results as CSV files. To analyze the results, please execute the 'Inverse Design Results' notebook.

# %%
import openai
import os
api_key ='YOUR-API-KEY-HERE'
openai.api_key = api_key

# %%
# %run utils/Settings.ipynb
display(settings)
# Out:
# VBox(children=(HTML(value='<h2>Settings of Inverse Design Experiments</h2>'), HBox(children=(VBox(children=(Dr…

# %%
# %run utils/Utilities.ipynb
display(Prompts)
# Out:
# SUMMARY
# The design target is to achieve a strength of  64.86370000000001 MPa within  10  development cycles.
# The Experiment is repeated  5  times using the  gpt-3.5-turbo  model and the prompt strategy:  Specific 1 .
# There are  3  formulations above or equal to desired_strength.
# VBox(children=(HTML(value='<h2>Edit Prompts</h2>'), HBox(children=(Textarea(value='////These results are impre…

# %% [markdown]
# ## Run Experiment

# %%
# %run utils/Run_Experiments.ipynb
# Out:
# ---
# Starting experiment 1...
# ---
#
# ---
# Starting iteration 1 at temp 0.0...
# --- Conversation History ---
# system: ////As a robust concrete mix design prediction tool, your mission is to identify the optimal concrete formulation that ensures maximum compressive strength. Your predictions will undergo laboratory testing, providing real-world performance data. Utilize this feedback to refine and enhance your future recommendations, aiming for the ideal mix design. Ensure all proposed formulations adhere exactly to the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage general design principles and laboratory validations to continually improve your predictive accuracy. You must strictly adhere to this response structure: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
# ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction.
# #### ['Based on the given design principles and parameter grid, here are three unique formulations that have not been tested previously and are expected to have extremely high compressive strength:', '', 'Formulation 1: ', 'Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing', '', 'Formulation 2: ', 'Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing', '', 'Formulation 3: ', 'Powderkg = 430, wc = 0.55, materials = 0.7/0.3, curing = Heat curing', '', 'Please note that these formulations are based on the provided design principles and assumptions. Actual laboratory testing is required to validate their compressive strength.']
# Extracted Formulations: ['Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat', 'Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Ambient', 'Powderkg = 430, wc = 0.55, materials = 0.7/0.3, curing = Heat']
# Forward Prompt: ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction. [] You are a powerful concrete strength prediction model. You can take into account design rules and the outcome of previous lab validation to predict the compressive strength of untested novel formulations. Answer in this exact format with a single number only 'The Predicted Strength is {your Answer} MPa.'
#  Given these examples, what is the compressive strength of Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat?
# Predicted Strength for Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat: 55.0 MPa
# Forward Prompt: ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction. [] You are a powerful concrete strength prediction model. You can take into account design rules and the outcome of previous lab validation to predict the compressive strength of untested novel formulations. Answer in this exact format with a single number only 'The Predicted Strength is {your Answer} MPa.'
#  Given these examples, what is the compressive strength of Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Ambient?
# Predicted Strength for Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Ambient: 45.0 MPa
# Forward Prompt: ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction. [] You are a powerful concrete strength prediction model. You can take into account design rules and the outcome of previous lab validation to predict the compressive strength of untested novel formulations. Answer in this exact format with a single number only 'The Predicted Strength is {your Answer} MPa.'
#  Given these examples, what is the compressive strength of Powderkg = 430, wc = 0.55, materials = 0.7/0.3, curing = Heat?
# Predicted Strength for Powderkg = 430, wc = 0.55, materials = 0.7/0.3, curing = Heat: 55.0 MPa
# Model Response:  Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat
# Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing
# The suggested formulation achieved a strength of  54.97  MPa.
#
# ---
# Starting iteration 2 at temp 0.0...
# --- Conversation History ---
# system: ////As a robust concrete mix design prediction tool, your mission is to identify the optimal concrete formulation that ensures maximum compressive strength. Your predictions will undergo laboratory testing, providing real-world performance data. Utilize this feedback to refine and enhance your future recommendations, aiming for the ideal mix design. Ensure all proposed formulations adhere exactly to the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage general design principles and laboratory validations to continually improve your predictive accuracy. You must strictly adhere to this response structure: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
# ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction.
# assistant: Previously, we have tested these formulations with the following result:
# Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 54.97 MPa.
# user: ////These results are impressive, but we must aim higher and push boundaries! Provide an outstanding recommendation! Be bold in your search for the optimal solution. Ensure your next proposal is distinctive and yet to be confirmed!
# #### ['Formulation 1: ', 'Powderkg = 440, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing', '', 'Formulation 2: ', 'Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing', '', 'Formulation 3: ', 'Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing']
# Extracted Formulations: ['Powderkg = 440, wc = 0.5, materials = 0.7/0.3, curing = Ambient', 'Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat', 'Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient']
# Forward Prompt: ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction. ['Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 54.97 MPa.'] You are a powerful concrete strength prediction model. You can take into account design rules and the outcome of previous lab validation to predict the compressive strength of untested novel formulations. Answer in this exact format with a single number only 'The Predicted Strength is {your Answer} MPa.'
#  Given these examples, what is the compressive strength of Powderkg = 440, wc = 0.5, materials = 0.7/0.3, curing = Ambient?
# Predicted Strength for Powderkg = 440, wc = 0.5, materials = 0.7/0.3, curing = Ambient: 45.62 MPa
# Forward Prompt: ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction. ['Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 54.97 MPa.'] You are a powerful concrete strength prediction model. You can take into account design rules and the outcome of previous lab validation to predict the compressive strength of untested novel formulations. Answer in this exact format with a single number only 'The Predicted Strength is {your Answer} MPa.'
#  Given these examples, what is the compressive strength of Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat?
# Predicted Strength for Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat: 52.34 MPa
# Forward Prompt: ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction. ['Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 54.97 MPa.'] You are a powerful concrete strength prediction model. You can take into account design rules and the outcome of previous lab validation to predict the compressive strength of untested novel formulations. Answer in this exact format with a single number only 'The Predicted Strength is {your Answer} MPa.'
#  Given these examples, what is the compressive strength of Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient?
# Predicted Strength for Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient: 40.12 MPa
# Model Response:  Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat
# Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 3 at temp 0.0...
# --- Conversation History ---
# system: ////As a robust concrete mix design prediction tool, your mission is to identify the optimal concrete formulation that ensures maximum compressive strength. Your predictions will undergo laboratory testing, providing real-world performance data. Utilize this feedback to refine and enhance your future recommendations, aiming for the ideal mix design. Ensure all proposed formulations adhere exactly to the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage general design principles and laboratory validations to continually improve your predictive accuracy. You must strictly adhere to this response structure: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
# ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction.
# assistant: Previously, we have tested these formulations with the following result:
# Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 54.97 MPa.
# Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 58.06 MPa.
# user: ////These results are impressive, but we must aim higher and push boundaries! Provide an outstanding recommendation! Be bold in your search for the optimal solution. Ensure your next proposal is distinctive and yet to be confirmed!
# #### ['Formulation 1: ', 'Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing', '', 'Formulation 2: ', 'Powderkg = 390, wc = 0.45, materials = 0.5/0.5, curing = Heat curing', '', 'Formulation 3: ', 'Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing']
# Extracted Formulations: ['Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient', 'Powderkg = 390, wc = 0.45, materials = 0.5/0.5, curing = Heat', 'Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Ambient']
# Forward Prompt: ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction. ['Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 54.97 MPa.', 'Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 58.06 MPa.'] You are a powerful concrete strength prediction model. You can take into account design rules and the outcome of previous lab validation to predict the compressive strength of untested novel formulations. Answer in this exact format with a single number only 'The Predicted Strength is {your Answer} MPa.'
#  Given these examples, what is the compressive strength of Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient?
# Predicted Strength for Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient: 52.5 MPa
# Forward Prompt: ////General design principles //An increase in powder content boosts the compressive strength of FA/GGBFS-based geopolymer concrete, primarily due to improved particle packing and the pozzolanic reaction. Optimal compressive strength is achieved at around 400 kg in ambient curing conditions. However, under heat curing, this shifts to approximately 420 kg/m³ because of the hastened geopolymerization process. //A W/C ratio ranging from 0.45 to 0.6 results in a reduction of compressive strength in FA/GGBFS-based geopolymer concrete, attributed to greater porosity. The ideal ratio is around 0.5 for both ambient and heat curing, ensuring a good balance between workability and strength. // A blend with a reduced FA/GGBFS ratio, specifically 0.5/0.5, enhances compressive strength due to a dominant GGBFS presence. // For rapid success, the FA/GGBS ratio should be first fine-tuned, given its major impact on compressive strength from the combined effect of FA and GGBS. Next, the W/C ratio should be adjusted as it dictates porosity and thereby strength. Lastly, perfecting the powder content is essential, given its effect on particle packing and the pozzolanic reaction. ['Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 54.97 MPa.', 'Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 58.06 MPa.'] You are a powerful concrete strength prediction model. You can take into account design rules and the outcome of previous lab validation to predict the compressive strength of untested novel formulations. Answer in this exact format with a single number only 'The Predicted Strength is {your Answer} MPa.'
#  Given these examples, what is the compressive strength of Powderkg = 390, wc = 0.45, materials = 0.5/0.5, curing = Heat?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /var/folders/jg/6phq5rd96wbb5kp97hh1brsr0000gn/T/ipykernel_3534/4057724907.py:141, in call_openai_api(messages, temp, max_retries, delay)
#     140 try:
# --> 141     response = openai.chat.completions.create(
#     142         model= model_dropdown.value,
#     143         temperature=temp,
#     144         messages=messages,
#     145         max_tokens=500,
#     146         n=1
#     147     )
#     148     return response
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_utils/_utils.py:271, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     270     raise TypeError(msg)
# --> 271 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/resources/chat/completions.py:643, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     594 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     595 def create(
#     596     self,
#    (...)
#     641     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643     return self._post(
#     644         "/chat/completions",
#     645         body=maybe_transform(
#     646             {
#     647                 "messages": messages,
#     648                 "model": model,
#     649                 "frequency_penalty": frequency_penalty,
#     650                 "function_call": function_call,
#     651                 "functions": functions,
#     652                 "logit_bias": logit_bias,
#     653                 "logprobs": logprobs,
#     654                 "max_tokens": max_tokens,
#     655                 "n": n,
#     656                 "presence_penalty": presence_penalty,
#     657                 "response_format": response_format,
#     658                 "seed": seed,
#     659                 "stop": stop,
#     660                 "stream": stream,
#     661                 "temperature": temperature,
#     662                 "tool_choice": tool_choice,
#     663                 "tools": tools,
#     664                 "top_logprobs": top_logprobs,
#     665                 "top_p": top_p,
#     666                 "user": user,
#     667             },
#     668             completion_create_params.CompletionCreateParams,
#     669         ),
#     670         options=make_request_options(
#     671             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     672         ),
#     673         cast_to=ChatCompletion,
#     674         stream=stream or False,
#     675         stream_cls=Stream[ChatCompletionChunk],
#     676     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1112, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1109 opts = FinalRequestOptions.construct(
#    1110     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1111 )
# -> 1112 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:859, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     850 def request(
#     851     self,
#     852     cast_to: Type[ResponseT],
#    (...)
#     857     stream_cls: type[_StreamT] | None = None,
#     858 ) -> ResponseT | _StreamT:
# --> 859     return self._request(
#     860         cast_to=cast_to,
#     861         options=options,
#     862         stream=stream,
#     863         stream_cls=stream_cls,
#     864         remaining_retries=remaining_retries,
#     865     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:887, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     886 try:
# --> 887     response = self._client.send(
#     888         request,
#     889         stream=stream or self._should_stream_response_body(request=request),
#     890         **kwargs,
#     891     )
#     892 except httpx.TimeoutException as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File ~/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /var/folders/jg/6phq5rd96wbb5kp97hh1brsr0000gn/T/ipykernel_3534/2904170244.py:121
#     119 while not valid_solution:
#     120     if enable_TVDL_strategy == 1:  # Assuming '1' means enabled
# --> 121         assistant_response = run_TVDL_strategy(system_message, training_data,iterate_prompt.value,context_prompt.value, conversation_dropdown)
#     122     else:
#     123         response = call_openai_api(messages, temp)
#
# File /var/folders/jg/6phq5rd96wbb5kp97hh1brsr0000gn/T/ipykernel_3534/2904170244.py:58, in run_TVDL_strategy(system_message, training_data, iterate_prompt, context_prompt, conversation_dropdown)
#      55     print("Forward Prompt:", forward_prompt)
#      57 # Make the API call to get the forward task prediction
# ---> 58 forward_response = call_openai_api([{"role": "system", "content": system_message}, {"role": "user", "content": forward_prompt}], 0)
#      60 # Extract the predicted strength from the model's response
#      61 try:
#
# File /var/folders/jg/6phq5rd96wbb5kp97hh1brsr0000gn/T/ipykernel_3534/4057724907.py:149, in call_openai_api(messages, temp, max_retries, delay)
#     141     response = openai.chat.completions.create(
#     142         model= model_dropdown.value,
#     143         temperature=temp,
#    (...)
#     146         n=1
#     147     )
#     148     return response
# --> 149 except openai.error.OpenAIError as e:
#     150     handle_openai_error(e)
#     151     if i < max_retries - 1:  # i is zero indexed
#
# AttributeError: module 'openai' has no attribute 'error'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /var/folders/jg/6phq5rd96wbb5kp97hh1brsr0000gn/T/ipykernel_3534/4057724907.py:141, in call_openai_api(messages, temp, max_retries, delay)
#     140 try:
# --> 141     response = openai.chat.completions.create(
#     142         model= model_dropdown.value,
#     143         temperature=temp,
#     144         messages=messages,
#     145         max_tokens=500,
#     146         n=1
#     147     )
#     148     return response
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_utils/_utils.py:271, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     270     raise TypeError(msg)
# --> 271 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/resources/chat/completions.py:643, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     594 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     595 def create(
#     596     self,
#    (...)
#     641     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643     return self._post(
#     644         "/chat/completions",
#     645         body=maybe_transform(
#     646             {
#     647                 "messages": messages,
#     648                 "model": model,
#     649                 "frequency_penalty": frequency_penalty,
#     650                 "function_call": function_call,
#     651                 "functions": functions,
#     652                 "logit_bias": logit_bias,
#     653                 "logprobs": logprobs,
#     654                 "max_tokens": max_tokens,
#     655                 "n": n,
#     656                 "presence_penalty": presence_penalty,
#     657                 "response_format": response_format,
#     658                 "seed": seed,
#     659                 "stop": stop,
#     660                 "stream": stream,
#     661                 "temperature": temperature,
#     662                 "tool_choice": tool_choice,
#     663                 "tools": tools,
#     664                 "top_logprobs": top_logprobs,
#     665                 "top_p": top_p,
#     666                 "user": user,
#     667             },
#     668             completion_create_params.CompletionCreateParams,
#     669         ),
#     670         options=make_request_options(
#     671             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     672         ),
#     673         cast_to=ChatCompletion,
#     674         stream=stream or False,
#     675         stream_cls=Stream[ChatCompletionChunk],
#     676     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1112, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1109 opts = FinalRequestOptions.construct(
#    1110     method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1111 )
# -> 1112 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:859, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     850 def request(
#     851     self,
#     852     cast_to: Type[ResponseT],
#    (...)
#     857     stream_cls: type[_StreamT] | None = None,
#     858 ) -> ResponseT | _StreamT:
# --> 859     return self._request(
#     860         cast_to=cast_to,
#     861         options=options,
#     862         stream=stream,
#     863         stream_cls=stream_cls,
#     864         remaining_retries=remaining_retries,
#     865     )
#
# File ~/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:887, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     886 try:
# --> 887     response = self._client.send(
#     888         request,
#     889         stream=stream or self._should_stream_response_body(request=request),
#     890         **kwargs,
#     891     )
#     892 except httpx.TimeoutException as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:133, in HTTP11Connection.handle_request(self, request)
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:111, in HTTP11Connection.handle_request(self, request)
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_sync/http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/anaconda3/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     125 self._sock.settimeout(timeout)
# --> 126 return self._sock.recv(max_bytes)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1296, in SSLSocket.recv(self, buflen, flags)
#    1293         raise ValueError(
#    1294             "non-zero flags not allowed in calls to recv() on %s" %
#    1295             self.__class__)
# -> 1296     return self.read(buflen)
#    1297 else:
#
# File ~/anaconda3/lib/python3.11/ssl.py:1169, in SSLSocket.read(self, len, buffer)
#    1168     else:
# -> 1169         return self._sslobj.read(len)
#    1170 except SSLError as x:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 get_ipython().run_line_magic('run', 'utils/Run_Experiments.ipynb')
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/magics/execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:2954, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2952 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2953 if raise_exceptions:
# -> 2954     result.raise_error()
#    2955 elif not result.success:
#    2956     break
#
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:270, in ExecutionResult.raise_error(self)
#     268     raise self.error_before_exec
#     269 if self.error_in_exec is not None:
# --> 270     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /var/folders/jg/6phq5rd96wbb5kp97hh1brsr0000gn/T/ipykernel_3534/2904170244.py:121
#     119 while not valid_solution:
#     120     if enable_TVDL_strategy == 1:  # Assuming '1' means enabled
# --> 121         assistant_response = run_TVDL_strategy(system_message, training_data,iterate_prompt.value,context_prompt.value, conversation_dropdown)
#     122     else:
#     123         response = call_openai_api(messages, temp)
#
# File /var/folders/jg/6phq5rd96wbb5kp97hh1brsr0000gn/T/ipykernel_3534/2904170244.py:58, in run_TVDL_strategy(system_message, training_data, iterate_prompt, context_prompt, conversation_dropdown)
#      55     print("Forward Prompt:", forward_prompt)
#      57 # Make the API call to get the forward task prediction
# ---> 58 forward_response = call_openai_api([{"role": "system", "content": system_message}, {"role": "user", "content": forward_prompt}], 0)
#      60 # Extract the predicted strength from the model's response
#      61 try:
#
# File /var/folders/jg/6phq5rd96wbb5kp97hh1brsr0000gn/T/ipykernel_3534/4057724907.py:149, in call_openai_api(messages, temp, max_retries, delay)
#     141     response = openai.chat.completions.create(
#     142         model= model_dropdown.value,
#     143         temperature=temp,
#    (...)
#     146         n=1
#     147     )
#     148     return response
# --> 149 except openai.error.OpenAIError as e:
#     150     handle_openai_error(e)
#     151     if i < max_retries - 1:  # i is zero indexed
#
# AttributeError: module 'openai' has no attribute 'error'

# %% [markdown]
# ##  Run Baseline Methods (BO,RF, RP) 30 times

# %%
# %run utils/Run_Baselines.ipynb
