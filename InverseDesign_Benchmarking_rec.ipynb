# %% [markdown]
# ## Usage Guidelines for this Jupyter Notebook
#
# ### Important Precautions
#
# - **Unsupervised Execution**: Avoid running this notebook unsupervised. Despite our efforts to develop robust code, it may occasionally get stuck in an infinite loop, where each iteration can incur costs.
# - **GPT-4 Model**: Exercise caution when using the GPT-4 model due to its high expense.
# - **Cell Execution**: Execute each cell individually and sequentially to ensure settings from the previous cell are correctly passed to the subsequent one.
# - **Save Prompts**: Make sure to click the save button if you have changed the prompts. This will overwrite your previous prompts.
#
#
# ### Usage Instructions
#
# - **Dependencies**: This notebook relies on `ID_Utilities` and `ID_Settings` notebooks. You may need to debug these notebooks as well.
# - **Result Analysis**: This notebook only generates results as CSV files. To analyze the results, please execute the 'Inverse Design Results' notebook.

# %%
# %run utils/ID_settings_rec.ipynb
display(settings)
# Out:
# VBox(children=(HTML(value='<h2>Settings of Inverse Design Experiments</h2>'), HBox(children=(VBox(children=(Dr…

# %%
# %run utils/ID_Utilities_rec.ipynb
display(Prompts)
# Out:
# SUMMARY
# The design target is to achieve a strength of  64.86370000000001 MPa within  10  development cycles.
# The Experiment is repeated  5  times using the  gpt-3.5-turbo  model and the prompt strategy:  None 1 .
# There are  3  formulations above or equal to desired_strength.
# VBox(children=(HTML(value='<h2>Edit Prompts</h2>'), HBox(children=(Textarea(value="//// These results are impr…

# %% [markdown]
# ## Run Experiment

# %%
# %run utils/Run_experiments_rec.ipynb
# Out:
# ---
# Starting experiment 1...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  37.18  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  57.54  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 57.54 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  54.31  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 57.54 MPa.
# The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 54.31 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 440, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing.
# The suggested formulation achieved a strength of  25.88  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 57.54 MPa.
# The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 54.31 MPa.
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing. resulted in a strength of 25.88 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  49.83  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 57.54 MPa.
# The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 54.31 MPa.
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing. resulted in a strength of 25.88 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 49.83 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  60.18  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 57.54 MPa.
# The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 54.31 MPa.
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing. resulted in a strength of 25.88 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 49.83 MPa.
# The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing. resulted in a strength of 60.18 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 380, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  33.03  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 57.54 MPa.
# The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 54.31 MPa.
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing. resulted in a strength of 25.88 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 49.83 MPa.
# The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing. resulted in a strength of 60.18 MPa.
# The formulation is Powderkg = 380, wc = 0.55, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 33.03 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  53.79  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 57.54 MPa.
# The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 54.31 MPa.
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing. resulted in a strength of 25.88 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 49.83 MPa.
# The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing. resulted in a strength of 60.18 MPa.
# The formulation is Powderkg = 380, wc = 0.55, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 33.03 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 53.79 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 410, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  40.59  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 37.18 MPa.
# The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 57.54 MPa.
# The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 54.31 MPa.
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing. resulted in a strength of 25.88 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 49.83 MPa.
# The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing. resulted in a strength of 60.18 MPa.
# The formulation is Powderkg = 380, wc = 0.55, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 33.03 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing. resulted in a strength of 53.79 MPa.
# The formulation is Powderkg = 410, wc = 0.45, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 40.59 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 400, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  47.28  MPa.
# Data for experiment 1 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_None 1_prompt_experiment_1_temp_0.7_target_99_%_Dev_Budget_10_recursive_0_1698997719.csv.
#
# ---
# Starting experiment 2...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# Model Response:  The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing
# The suggested formulation achieved a strength of  59.88  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing resulted in a strength of 58.06 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# The suggested formulation achieved a strength of  40.78  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing resulted in a strength of 58.06 MPa.
# The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 40.78 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = heat curing.
# The suggested formulation achieved a strength of  29.46  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing resulted in a strength of 58.06 MPa.
# The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 40.78 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 29.46 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = ambient curing.
# The suggested formulation achieved a strength of  50.89  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing resulted in a strength of 58.06 MPa.
# The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 40.78 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 29.46 MPa.
# The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = ambient curing. resulted in a strength of 50.89 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 420, wc = 0.6, materials = 0.7/0.3, curing = heat curing.
# The suggested formulation achieved a strength of  26.89  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing resulted in a strength of 58.06 MPa.
# The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 40.78 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 29.46 MPa.
# The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = ambient curing. resulted in a strength of 50.89 MPa.
# The formulation is Powderkg = 420, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 26.89 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = ambient curing.
# The suggested formulation achieved a strength of  47.13  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing resulted in a strength of 58.06 MPa.
# The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 40.78 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 29.46 MPa.
# The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = ambient curing. resulted in a strength of 50.89 MPa.
# The formulation is Powderkg = 420, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 26.89 MPa.
# The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = ambient curing. resulted in a strength of 47.13 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing resulted in a strength of 58.06 MPa.
# The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 40.78 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 29.46 MPa.
# The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = ambient curing. resulted in a strength of 50.89 MPa.
# The formulation is Powderkg = 420, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 26.89 MPa.
# The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = ambient curing. resulted in a strength of 47.13 MPa.
# The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 38.63 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = ambient curing.
# The suggested formulation achieved a strength of  46.27  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing resulted in a strength of 59.88 MPa.
# The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing resulted in a strength of 58.06 MPa.
# The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 40.78 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 29.46 MPa.
# The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = ambient curing. resulted in a strength of 50.89 MPa.
# The formulation is Powderkg = 420, wc = 0.6, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 26.89 MPa.
# The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = ambient curing. resulted in a strength of 47.13 MPa.
# The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing. resulted in a strength of 38.63 MPa.
# The formulation is Powderkg = 430, wc = 0.6, materials = 0.6/0.4, curing = ambient curing. resulted in a strength of 46.27 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 450, wc = 0.55, materials = 0.7/0.3, curing = ambient curing.
# The suggested formulation achieved a strength of  25.71  MPa.
# Data for experiment 2 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_None 1_prompt_experiment_2_temp_0.7_target_99_%_Dev_Budget_10_recursive_0_1698997733.csv.
#
# ---
# Starting experiment 3...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# Model Response:  The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = Heat curing
# The suggested formulation achieved a strength of  53.2  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.2 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing.
# The suggested formulation achieved a strength of  20.76  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.2 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing. resulted in a strength of 20.76 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 370, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  56.11  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.2 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing. resulted in a strength of 20.76 MPa.
# The formulation is Powderkg = 370, wc = 0.45, materials = 0.6/0.4, curing = Heat curing. resulted in a strength of 56.11 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.35  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# --- Conversation History ---
# ...
#
# ---
# Starting iteration 4 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 33.83 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.79 MPa.
# The formulation is Powderkg = 430, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 57.37 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.5  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 33.83 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.79 MPa.
# The formulation is Powderkg = 430, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 57.37 MPa.
# The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 43.5 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.38  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 33.83 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.79 MPa.
# The formulation is Powderkg = 430, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 57.37 MPa.
# The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 43.5 MPa.
# The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing. resulted in a strength of 45.38 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 33.83 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.79 MPa.
# The formulation is Powderkg = 430, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 57.37 MPa.
# The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 43.5 MPa.
# The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing. resulted in a strength of 45.38 MPa.
# The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 38.63 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  47.13  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 33.83 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.79 MPa.
# The formulation is Powderkg = 430, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 57.37 MPa.
# The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 43.5 MPa.
# The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing. resulted in a strength of 45.38 MPa.
# The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 38.63 MPa.
# The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing. resulted in a strength of 47.13 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  50.43  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 33.83 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.79 MPa.
# The formulation is Powderkg = 430, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 57.37 MPa.
# The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 43.5 MPa.
# The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing. resulted in a strength of 45.38 MPa.
# The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 38.63 MPa.
# The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing. resulted in a strength of 47.13 MPa.
# The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing. resulted in a strength of 50.43 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  48.91  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# --- Conversation History ---
# system: ////You are an advanced prediction model tasked to predict a concrete formulation for maximum compressive strength. Your predicted formulation will undergo laboratory testing, providing real-world performance data to enhance your future recommendations. Ensure each formulation lies exactly on the following parameter grid //Powder content in kg: 360, 370, 380, 390, 400, 410, 420, 430, 440, 450 //Water-to-cement (WC) ratio: 0.45, 0.5, 0.55, 0.6 //Materials: Fly-Ash/GGBFS at ratios of 0.7/0.3, 0.6/0.4, 0.5/0.5 //Curing methods: Ambient curing/Heat curing ////Leverage laboratory validations to improve your predictions. It is very important that you adhere to this format in your answer without any additional details or context: 'The formulation is Powderkg = {your estimate}, wc = {your estimate}, materials = {your estimate}, curing = {your estimate}'
#
# assistant: Previously, we have tested these formulations with the following result:
# The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing resulted in a strength of 33.83 MPa.
# The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing resulted in a strength of 53.79 MPa.
# The formulation is Powderkg = 430, wc = 0.55, materials = 0.6/0.4, curing = Heat curing resulted in a strength of 57.37 MPa.
# The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 43.5 MPa.
# The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing. resulted in a strength of 45.38 MPa.
# The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing. resulted in a strength of 38.63 MPa.
# The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing. resulted in a strength of 47.13 MPa.
# The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing. resulted in a strength of 50.43 MPa.
# The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing. resulted in a strength of 48.91 MPa.
# user: //// These results are impressive! Nevertheless, we must strive for excellence and push the boundaries! Provide me with a superior formulation! It might require a bold move to uncover the optimal solution. Ensure that your forthcoming suggestion is distinctive and hasn't been validated previously!
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  31.67  MPa.
# Data for experiment 5 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_None 1_prompt_experiment_5_temp_0.7_target_99_%_Dev_Budget_10_recursive_0_1698998390.csv.

# %% [markdown]
# ##  Run Baseline Methods (BO,RF, RP) 30 times

# %%
# %run utils/Baselines.ipynb
