# %% [markdown]
# ## Usage Guidelines for this Jupyter Notebook
#
# ### Important Precautions
#
# - **Unsupervised Execution**: Avoid running this notebook unsupervised. Despite our efforts to develop robust code, it may occasionally get stuck in an infinite loop, where each iteration can incur costs.
# - **GPT-4 Model**: Exercise caution when using the GPT-4 model due to its high expense.
# - **Cell Execution**: Execute each cell individually and sequentially to ensure settings from the previous cell are correctly passed to the subsequent one.
# - **Save Prompts**: Make sure to click the save button if you have changed the prompts. This will overwrite your previous prompts.
#
#
# ### Usage Instructions
#
# - **Dependencies**: This notebook relies on `ID_Utilities` and `ID_Settings` notebooks. You may need to debug these notebooks as well.
# - **Result Analysis**: This notebook only generates results as CSV files. To analyze the results, please execute the 'Inverse Design Results' notebook.

# %%
# %run utils/ID_settings_rec.ipynb
display(settings)
# Out:
# VBox(children=(HTML(value='<h2>Settings of Inverse Design Experiments</h2>'), HBox(children=(VBox(children=(Dr…

# %%
# %run utils/ID_Utilities_rec.ipynb
display(Prompts)
# Out:
# SUMMARY
# The design target is to achieve a strength of  64.86370000000001 MPa within  10  development cycles.
# The Experiment is repeated  5  times using the  gpt-3.5-turbo  model and the prompt strategy:  None 0 .
# There are  3  formulations above or equal to desired_strength.
# VBox(children=(HTML(value='<h2>Edit Prompts</h2>'), HBox(children=(Textarea(value='//// These are great Result…

# %% [markdown]
# ## Run Experiment

# %%
# %run utils/Run_experiments_rec.ipynb
# Out:
# ---
# Starting experiment 1...
# ---
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing
# The suggested formulation achieved a strength of  53.79  MPa.
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.84  MPa.
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  46.98  MPa.
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.38  MPa.
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.03  MPa.
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.96  MPa.
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing.
# The suggested formulation achieved a strength of  20.76  MPa.
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  62.29  MPa.
# Data for experiment 1 and temp 0.0 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_1_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1699005063.csv.
#
# ---
# Starting experiment 2...
# ---
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  53.79  MPa.
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.84  MPa.
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  46.98  MPa.
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is Powderkg = 390, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  57.2  MPa.
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing.
# The suggested formulation achieved a strength of  37.52  MPa.
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  46.48  MPa.
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is Powderkg = 440, wc = 0.6, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  28.65  MPa.
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.88  MPa.
# Data for experiment 2 and temp 0.0 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_2_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1699005077.csv.
#
# ---
# Starting experiment 3...
# ---
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  53.79  MPa.
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.84  MPa.
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  46.98  MPa.
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.38  MPa.
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.03  MPa.
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is Powderkg = 440, wc = 0.6, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  51.98  MPa.
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  60.38  MPa.
# Data for experiment 3 and temp 0.0 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_3_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1699005091.csv.
#
# ---
# Starting experiment 4...
# ---
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  53.79  MPa.
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.84  MPa.
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  46.98  MPa.
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.38  MPa.
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.03  MPa.
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  57.27  MPa.
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  51.22  MPa.
# Data for experiment 4 and temp 0.0 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_4_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1699005103.csv.
#
# ---
# Starting experiment 5...
# ---
#
# ---
# Starting iteration 1 at temp 0.0...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  53.79  MPa.
#
# ---
# Starting iteration 3 at temp 0.0...
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 4 at temp 0.0...
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.84  MPa.
#
# ---
# Starting iteration 5 at temp 0.0...
# Model Response:  The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  46.98  MPa.
#
# ---
# Starting iteration 6 at temp 0.0...
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.38  MPa.
#
# ---
# Starting iteration 7 at temp 0.0...
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.03  MPa.
#
# ---
# Starting iteration 8 at temp 0.0...
# Model Response:  The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  57.27  MPa.
#
# ---
# Starting iteration 9 at temp 0.0...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing.
# The suggested formulation achieved a strength of  20.76  MPa.
#
# ---
# Starting iteration 10 at temp 0.0...
# Model Response:  The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  50.64  MPa.
# Data for experiment 5 and temp 0.0 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_5_temp_0.0_target_99_%_Dev_Budget_10_recursive_0_1699005115.csv.
#
# ---
# Starting experiment 1...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# Model Response:  The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = Heat curing
# The suggested formulation achieved a strength of  50.9  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.38  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# Model Response:  The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.35  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# Model Response:  The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  51.4  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.88  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# Model Response:  The formulation is Powderkg = 430, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  32.59  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  51.22  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# Model Response:  The formulation is Powderkg = 440, wc = 0.6, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  28.65  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# Model Response:  The formulation is Powderkg = 370, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  41.34  MPa.
# Data for experiment 1 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_1_temp_0.7_target_99_%_Dev_Budget_10_recursive_0_1699005128.csv.
#
# ---
# Starting experiment 2...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = ambient.
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# Model Response:  The formulation is Powderkg = 410, wc = 0.6, materials = 0.5/0.5, curing = heat.
# The suggested formulation achieved a strength of  49.91  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# Model Response:  The formulation is Powderkg = 380, wc = 0.55, materials = 0.6/0.4, curing = ambient.
# The suggested formulation achieved a strength of  46.12  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = heat.
# The suggested formulation achieved a strength of  29.46  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.7/0.3, curing = ambient.
# The suggested formulation achieved a strength of  38.43  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# Model Response:  The formulation is Powderkg = 370, wc = 0.45, materials = 0.5/0.5, curing = heat.
# The suggested formulation achieved a strength of  61.22  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# Model Response:  The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = heat.
# The suggested formulation achieved a strength of  55.82  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = heat.
# The suggested formulation achieved a strength of  43.03  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# Model Response:  The formulation is Powderkg = 400, wc = 0.6, materials = 0.5/0.5, curing = heat.
# The suggested formulation achieved a strength of  50.41  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = ambient.
# The suggested formulation achieved a strength of  33.81  MPa.
# Data for experiment 2 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_2_temp_0.7_target_99_%_Dev_Budget_10_recursive_0_1699005141.csv.
#
# ---
# Starting experiment 3...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# Model Response:  The formulation is Powderkg = 380, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  52.46  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# Model Response:  The formulation is Powderkg = 390, wc = 0.6, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  53.96  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# Model Response:  The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  39.8  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  47.64  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# Model Response:  The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  50.43  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# Model Response:  The formulation is Powderkg = 400, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  58.98  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# Model Response:  The formulation is Powderkg = 420, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  31.24  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# Model Response:  The formulation is Powderkg = 450, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  44.49  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# Model Response:  The formulation is Powderkg = 380, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing.
# The suggested formulation achieved a strength of  25.5  MPa.
# Data for experiment 3 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_3_temp_0.7_target_99_%_Dev_Budget_10_recursive_0_1699005154.csv.
#
# ---
# Starting experiment 4...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  53.79  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing.
# The suggested formulation achieved a strength of  37.18  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# Model Response:  The formulation is Powderkg = 430, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  47.59  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  62.29  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# Model Response:  The formulation is Powderkg = 380, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  33.03  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# Model Response:  The formulation is Powderkg = 405, wc = 0.52, materials = 0.6/0.4, curing = Ambient curing.
# No match found for suggestion string:  The formulation is Powderkg = 405, wc = 0.52, materials = 0.6/0.4, curing = Ambient curing
# Iteration 8: No matching lab result found for suggestion {'powderkg': '405', 'wc': '0.52', 'materials': '0.6/0.4', 'curing': 'Ambient curing'}
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  49.59  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# Model Response:  The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  51.4  MPa.
# Data for experiment 4 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_4_temp_0.7_target_99_%_Dev_Budget_10_recursive_0_1699005170.csv.
#
# ---
# Starting experiment 5...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# Model Response:  The formulation is Powderkg = 360, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing
# The suggested formulation achieved a strength of  33.83  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# Model Response:  The formulation is Powderkg = 370, wc = 0.6, materials = 0.5/0.5, curing = Heat curing
# The suggested formulation achieved a strength of  51.9  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# Model Response:  The formulation is Powderkg = 450, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  54.38  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# Model Response:  The formulation is Powderkg = 440, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  44.18  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# Model Response:  The formulation is Powderkg = 410, wc = 0.6, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  46.5  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# Model Response:  The formulation is Powderkg = 430, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  56.66  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  45.38  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing.
# The suggested formulation achieved a strength of  37.18  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# Model Response:  The formulation is Powderkg = 420, wc = 0.6, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  26.89  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  48.91  MPa.
# Data for experiment 5 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_None 0_prompt_experiment_5_temp_0.7_target_99_%_Dev_Budget_10_recursive_0_1699005184.csv.

# %% [markdown]
# ##  Run Baseline Methods (BO,RF, RP) 30 times

# %%
# %run utils/Baselines.ipynb
