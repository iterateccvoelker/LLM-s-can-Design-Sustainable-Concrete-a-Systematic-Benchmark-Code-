# %% [markdown]
# ## Usage Guidelines for this Jupyter Notebook
#
# ### Important Precautions
#
# - **Unsupervised Execution**: Avoid running this notebook unsupervised. Despite our efforts to develop robust code, it may occasionally get stuck in an infinite loop, where each iteration can incur costs.
# - **GPT-4 Model**: Exercise caution when using the GPT-4 model due to its high expense.
# - **Cell Execution**: Execute each cell individually and sequentially to ensure settings from the previous cell are correctly passed to the subsequent one.
# - **Save Prompts**: Make sure to click the save button if you have changed the prompts. This will overwrite your previous prompts.
#
#
# ### Usage Instructions
#
# - **Dependencies**: This notebook relies on `ID_Utilities` and `ID_Settings` notebooks. You may need to debug these notebooks as well.
# - **Result Analysis**: This notebook only generates results as CSV files. To analyze the results, please execute the 'Inverse Design Results' notebook.

# %%
# %run utils/ID_settings_rec.ipynb
display(settings)
# Out:
# VBox(children=(HTML(value='<h2>Settings of Inverse Design Experiments</h2>'), HBox(children=(VBox(children=(Dr…

# %%
# %run utils/ID_Utilities_rec.ipynb
display(Prompts)
# Out:
# SUMMARY
# The design target is to achieve a strength of  64.86370000000001 MPa within  10  development cycles.
# The Experiment is repeated  9  times using the  gpt-3.5-turbo  model and the prompt strategy:  Generic .
# There are  3  formulations above or equal to desired_strength.
# VBox(children=(HTML(value='<h2>Edit Prompts</h2>'), HBox(children=(Textarea(value='//// These are great Result…

# %% [markdown]
# ## Run Experiment

# %%
# %run utils/Run_experiments_rec.ipynb
# Out:
# ---
# Starting experiment 1...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing', 65.0), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing', 55.0), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing', 65.0)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing
# The suggested formulation achieved a strength of  54.97  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = Heat curing', 52.35)]
# final response The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = Heat curing
# Model Response:  The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = Heat curing
# The suggested formulation achieved a strength of  40.78  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 47.82), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.', 45.62), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing.', 38.92)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  61.95  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 55.12), ('The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 65.12), ('The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing.', 35.12)]
# final response The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  61.3  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing.', 45.5), ('The formulation is Powderkg = 410, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.', 55.2), ('The formulation is Powderkg = 450, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.', 47.82)]
# final response The formulation is Powderkg = 410, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 410, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.29  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing.', 35.12), ('The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.', 55.82), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.', 40.78)]
# final response The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  50.64  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.6, materials = 0.7/0.3, curing = Heat curing.', 42.12), ('The formulation is Powderkg = 450, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing.', 45.12), ('The formulation is Powderkg = 400, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing.', 35.12)]
# final response The formulation is Powderkg = 450, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing.
# The suggested formulation achieved a strength of  58.53  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Heat curing.', 42.12), ('The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.', 60.12), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing.', 40.78)]
# final response The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  55.82  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 40.78), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 56.12), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.', 40.78)]
# final response The formulation is Powderkg = 440, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  55.78  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing.', 38.12), ('The formulation is Powderkg = 440, wc = 0.6, materials = 0.6/0.4, curing = Ambient curing.', 45.12), ('The formulation is Powderkg = 410, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 40.78)]
# final response The formulation is Powderkg = 440, wc = 0.6, materials = 0.6/0.4, curing = Ambient curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.6, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  46.01  MPa.
# Data for experiment 1 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_1_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435421.csv.
#
# ---
# Starting experiment 2...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing', 55.0), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = heat curing', 55.0), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing', 65.0)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing
# The suggested formulation achieved a strength of  54.97  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing', 52.35), ('The formulation is Powderkg = 380, wc = 0.45, materials = 0.7/0.3, curing = heat curing', 50.32), ('The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = ambient curing', 45.12)]
# final response The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing
# Model Response:  The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing
# The suggested formulation achieved a strength of  61.51  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing', 55.12), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing', 61.51), ('The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = heat curing', 58.23)]
# final response The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing
# Model Response:  The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing
# The suggested formulation achieved a strength of  61.51  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = heat curing.', 58.23), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 55.12), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = ambient curing.', 45.12)]
# final response The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = heat curing.
# The suggested formulation achieved a strength of  53.2  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 55.5), ('The formulation is Powderkg = 370, wc = 0.5, materials = 0.5/0.5, curing = ambient curing.', 45.2), ('The formulation is Powderkg = 400, wc = 0.6, materials = 0.6/0.4, curing = heat curing.', 50.12)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 45.12), ('The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = heat curing.', 61.51), ('The formulation is Powderkg = 400, wc = 0.45, materials = 0.5/0.5, curing = heat curing.', 55.12)]
# final response The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  61.3  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.45, materials = 0.5/0.5, curing = heat curing.', 55.2), ('The formulation is Powderkg = 400, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 60.5), ('The formulation is Powderkg = 450, wc = 0.5, materials = 0.7/0.3, curing = ambient curing.', 35.2)]
# final response The formulation is Powderkg = 400, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  57.75  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 45.12), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = heat curing.', 55.2), ('The formulation is Powderkg = 390, wc = 0.45, materials = 0.6/0.4, curing = ambient curing.', 45.2)]
# final response The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = heat curing.
# The suggested formulation achieved a strength of  64.6  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = heat curing.', 61.51), ('The formulation is Powderkg = 390, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 42.5), ('The formulation is Powderkg = 380, wc = 0.5, materials = 0.5/0.5, curing = heat curing.', 55.2)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  61.95  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing.', 54.97), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing.', 61.51), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = heat curing.', 61.95)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  61.95  MPa.
# Data for experiment 2 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_2_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435476.csv.
#
# ---
# Starting experiment 3...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing', 35.0), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing', 55.0), ('The formulation is Powderkg = 440, wc = 0.55, materials = 0.5/0.5, curing = Heat curing', 55.0)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing
# The suggested formulation achieved a strength of  61.95  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing', 55.2), ('The formulation is Powderkg = 400, wc = 0.6, materials = 0.7/0.3, curing = Heat curing', 55.2), ('The formulation is Powderkg = 420, wc = 0.55, materials = 0.6/0.4, curing = Heat curing', 62.1)]
# final response The formulation is Powderkg = 420, wc = 0.55, materials = 0.6/0.4, curing = Heat curing
# Model Response:  The formulation is Powderkg = 420, wc = 0.55, materials = 0.6/0.4, curing = Heat curing
# The suggested formulation achieved a strength of  58.93  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 380, wc = 0.45, materials = 0.5/0.5, curing = Heat curing', 55.12), ('The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing', 45.12), ('The formulation is Powderkg = 450, wc = 0.6, materials = 0.6/0.4, curing = Heat curing', 55.0)]
# final response The formulation is Powderkg = 380, wc = 0.45, materials = 0.5/0.5, curing = Heat curing
# Model Response:  The formulation is Powderkg = 380, wc = 0.45, materials = 0.5/0.5, curing = Heat curing
# The suggested formulation achieved a strength of  60.47  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 62.5), ('The formulation is Powderkg = 450, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.', 62.5), ('The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = Ambient curing.', 55.82)]
# final response The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  39.8  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.5, materials = 0.7/0.3, curing = Heat curing. ', 65.2), ('The formulation is Powderkg = 390, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing. ', 45.2), ('The formulation is Powderkg = 410, wc = 0.6, materials = 0.6/0.4, curing = Heat curing.', 55.2)]
# final response The formulation is Powderkg = 450, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  44.49  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing. ', 55.12), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing. ', 45.2), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.', 55.12)]
# final response The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  64.6  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 390, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 42.3), ('The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.', 68.2), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.', 45.2)]
# final response The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  53.79  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 420, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.', 65.2), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.', 59.2), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.', 55.12)]
# final response The formulation is Powderkg = 420, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  64.28  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 39.8), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing.', 55.2), ('The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 62.15)]
# final response The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  61.61  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 390, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 62.15), ('The formulation is Powderkg = 380, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing.', 37.5), ('The formulation is Powderkg = 450, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.', 62.15)]
# final response The formulation is Powderkg = 390, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 390, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  59.73  MPa.
# Data for experiment 3 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_3_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435532.csv.
#
# ---
# Starting experiment 4...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.45, materials = 0.6/0.4, curing = heat curing', 55.0), ('The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = heat curing', 55.0), ('The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = heat curing', 65.0)]
# final response The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = heat curing
# Model Response:  The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = heat curing
# The suggested formulation achieved a strength of  54.38  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 52.15), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing.', 52.75), ('The formulation is Powderkg = 390, wc = 0.55, materials = 0.5/0.5, curing = ambient curing.', 45.12)]
# final response The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  61.51  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 55.72), ('The formulation is Powderkg = 400, wc = 0.6, materials = 0.6/0.4, curing = ambient curing.', 40.12), ('The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = heat curing.', 54.38)]
# final response The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# The suggested formulation achieved a strength of  39.8  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 55.12), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = ambient curing.', 42.5), ('The formulation is Powderkg = 400, wc = 0.55, materials = 0.5/0.5, curing = heat curing.', 55.12)]
# final response The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  57.27  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 390, wc = 0.5, materials = 0.5/0.5, curing = heat curing.', 50.12), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 52.5), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing.', 61.51)]
# final response The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = heat curing.', 55.12), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 55.2), ('The formulation is Powderkg = 390, wc = 0.55, materials = 0.6/0.4, curing = ambient curing.', 45.12)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.5, materials = 0.5/0.5, curing = heat curing.', 55.12), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 57.27), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.5/0.5, curing = heat curing.', 55.72)]
# final response The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  58.03  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = heat curing.', 55.12), ('The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = ambient curing.', 45.12), ('The formulation is Powderkg = 430, wc = 0.6, materials = 0.7/0.3, curing = heat curing.', 45.12)]
# final response The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  60.68  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = ambient curing.', 45.12), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = heat curing.', 54.38), ('The formulation is Powderkg = 440, wc = 0.6, materials = 0.5/0.5, curing = heat curing.', 55.12)]
# final response The formulation is Powderkg = 440, wc = 0.6, materials = 0.5/0.5, curing = heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.6, materials = 0.5/0.5, curing = heat curing.
# The suggested formulation achieved a strength of  52.42  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing.', 55.12), ('The formulation is Powderkg = 370, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 57.27), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = heat curing.', 54.38)]
# final response The formulation is Powderkg = 370, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 370, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  56.11  MPa.
# Data for experiment 4 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_4_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435588.csv.
#
# ---
# Starting experiment 5...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing', 65.0), ('The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = heat curing', 55.0), ('The formulation is Powderkg = 430, wc = 0.55, materials = 0.5/0.5, curing = heat curing', 55.0)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing. ', 37.82), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.5/0.5, curing = heat curing. ', 42.15), ('The formulation is Powderkg = 420, wc = 0.55, materials = 0.7/0.3, curing = ambient curing.', 32.45)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.5/0.5, curing = heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.5/0.5, curing = heat curing.
# The suggested formulation achieved a strength of  63.47  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 42.15), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = ambient curing.', 35.12), ('The formulation is Powderkg = 390, wc = 0.55, materials = 0.5/0.5, curing = heat curing.', 55.12)]
# final response The formulation is Powderkg = 390, wc = 0.55, materials = 0.5/0.5, curing = heat curing.
# Model Response:  The formulation is Powderkg = 390, wc = 0.55, materials = 0.5/0.5, curing = heat curing.
# The suggested formulation achieved a strength of  52.0  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 55.0), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = ambient curing.', 35.0), ('The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = heat curing.', 55.0)]
# final response The formulation is Powderkg = 410, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 410, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  58.29  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = heat curing.', 55.0), ('The formulation is Powderkg = 450, wc = 0.5, materials = 0.7/0.3, curing = ambient curing.', 35.0), ('The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = heat curing.', 45.0)]
# final response The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  55.82  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 38.63), ('The formulation is Powderkg = 400, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 58.29), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.5/0.5, curing = heat curing.', 60.0)]
# final response The formulation is Powderkg = 420, wc = 0.5, materials = 0.5/0.5, curing = heat curing.
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.5/0.5, curing = heat curing.
# The suggested formulation achieved a strength of  64.28  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing.', 70.0), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = ambient curing.', 45.0), ('The formulation is Powderkg = 420, wc = 0.55, materials = 0.7/0.3, curing = heat curing.', 56.0)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing.
# The suggested formulation achieved a strength of  54.97  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 400, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 40.0), ('The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = heat curing.', 60.0), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.5/0.5, curing = ambient curing.', 40.0)]
# final response The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  61.3  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.7/0.3, curing = ambient curing. ', 35.0), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = ambient curing. ', 45.0), ('The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = ambient curing.', 45.0)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = ambient curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = ambient curing.
# The suggested formulation achieved a strength of  51.04  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 390, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 38.63), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = heat curing.', 45.12), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 58.29)]
# final response The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  57.27  MPa.
# Data for experiment 5 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_5_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435644.csv.
#
# ---
# Starting experiment 6...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing', 55.0), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = heat curing', 55.0), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing', 65.0)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing
# The suggested formulation achieved a strength of  54.97  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing', 52.85), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.7/0.3, curing = heat curing', 52.35), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.5/0.5, curing = ambient curing', 45.12)]
# final response The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing
# Model Response:  The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = heat curing
# The suggested formulation achieved a strength of  57.27  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.6, materials = 0.7/0.3, curing = heat curing', 52.15), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = ambient curing', 45.12), ('The formulation is Powderkg = 400, wc = 0.55, materials = 0.5/0.5, curing = heat curing', 52.15)]
# final response The formulation is Powderkg = 410, wc = 0.6, materials = 0.7/0.3, curing = heat curing
# Model Response:  The formulation is Powderkg = 410, wc = 0.6, materials = 0.7/0.3, curing = heat curing
# The suggested formulation achieved a strength of  27.16  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = heat curing', 54.97), ('The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = heat curing', 55.82), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = heat curing', 45.82)]
# final response The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = heat curing
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.6/0.4, curing = heat curing
# The suggested formulation achieved a strength of  57.12  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.5, materials = 0.5/0.5, curing = heat curing', 55.82), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing', 55.12), ('The formulation is Powderkg = 390, wc = 0.55, materials = 0.6/0.4, curing = ambient curing', 45.82)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.5/0.5, curing = heat curing
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.5/0.5, curing = heat curing
# The suggested formulation achieved a strength of  63.47  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 420, wc = 0.45, materials = 0.7/0.3, curing = heat curing', 55.82), ('The formulation is Powderkg = 380, wc = 0.5, materials = 0.6/0.4, curing = ambient curing', 40.12), ('The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = heat curing', 63.47)]
# final response The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = heat curing
# Model Response:  The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = heat curing
# The suggested formulation achieved a strength of  54.38  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.45, materials = 0.7/0.3, curing = ambient curing.', 25.12), ('The formulation is Powderkg = 370, wc = 0.5, materials = 0.6/0.4, curing = heat curing.', 56.82), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.5/0.5, curing = ambient curing.', 45.62)]
# final response The formulation is Powderkg = 370, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 370, wc = 0.5, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  58.2  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 54.97), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = ambient curing.', 45.12), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.7/0.3, curing = heat curing.', 30.12)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 390, wc = 0.45, materials = 0.7/0.3, curing = heat curing.', 40.12), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = ambient curing.', 40.12), ('The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = heat curing.', 60.25)]
# final response The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = heat curing.
# Model Response:  The formulation is Powderkg = 420, wc = 0.55, materials = 0.5/0.5, curing = heat curing.
# The suggested formulation achieved a strength of  50.64  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.5, materials = 0.5/0.5, curing = ambient curing.', 45.12), ('The formulation is Powderkg = 390, wc = 0.45, materials = 0.6/0.4, curing = heat curing.', 56.85), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.7/0.3, curing = heat curing.', 45.82)]
# final response The formulation is Powderkg = 390, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# Model Response:  The formulation is Powderkg = 390, wc = 0.45, materials = 0.6/0.4, curing = heat curing.
# The suggested formulation achieved a strength of  57.2  MPa.
# Data for experiment 6 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_6_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435702.csv.
#
# ---
# Starting experiment 7...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 390, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 55.0), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 55.0), ('The formulation is Powderkg = 450, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.', 65.0)]
# final response The formulation is Powderkg = 450, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  35.2  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.', 38.5), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing.', 30.5), ('The formulation is Powderkg = 400, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.', 40.5)]
# final response The formulation is Powderkg = 400, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  51.54  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Heat curing. ', 48.9), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing. ', 30.5), ('The formulation is Powderkg = 390, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.', 45.8)]
# final response The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.03  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.', 60.5), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.', 45.6), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.5/0.5, curing = Ambient curing.', 45.6)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  56.56  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 55.2), ('The formulation is Powderkg = 440, wc = 0.6, materials = 0.7/0.3, curing = Heat curing.', 45.8), ('The formulation is Powderkg = 370, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing.', 30.5)]
# final response The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  62.29  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 55.8), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.', 45.6), ('The formulation is Powderkg = 430, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.', 55.8)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 55.2), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 58.03), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.', 40.2)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  61.95  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing.', 32.1), ('The formulation is Powderkg = 410, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing.', 40.12), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.', 51.54)]
# final response The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  64.6  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 38.63), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.', 59.45), ('The formulation is Powderkg = 390, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.', 63.2)]
# final response The formulation is Powderkg = 390, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  64.76  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.6, materials = 0.7/0.3, curing = Ambient curing.', 30.5), ('The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.', 59.12), ('The formulation is Powderkg = 450, wc = 0.6, materials = 0.5/0.5, curing = Ambient curing.', 45.8)]
# final response The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  55.82  MPa.
# Data for experiment 7 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_7_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435757.csv.
#
# ---
# Starting experiment 8...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing', 65.0), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing', 55.0), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.5/0.5, curing = Heat curing', 55.0)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing', 35.72), ('The formulation is Powderkg = 430, wc = 0.55, materials = 0.7/0.3, curing = Ambient curing', 35.72), ('The formulation is Powderkg = 420, wc = 0.6, materials = 0.5/0.5, curing = Heat curing', 35.12)]
# final response The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing
# Model Response:  The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing
# The suggested formulation achieved a strength of  61.61  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 40.12), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.', 45.12), ('The formulation is Powderkg = 400, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.', 45.12)]
# final response The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.
# Model Response:  The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.
# The suggested formulation achieved a strength of  51.22  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 55.12), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 55.12), ('The formulation is Powderkg = 390, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing.', 40.12)]
# final response The formulation is Powderkg = 410, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 410, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  58.24  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.', 45.78), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 60.0), ('The formulation is Powderkg = 400, wc = 0.6, materials = 0.6/0.4, curing = Heat curing.', 45.12)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  54.97  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 38.63), ('The formulation is Powderkg = 440, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 55.82), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.', 60.12)]
# final response The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.03  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing.', 50.0), ('The formulation is Powderkg = 440, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.', 55.12), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.', 58.24)]
# final response The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 38.63), ('The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 61.61), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.6/0.4, curing = Ambient curing.', 51.22)]
# final response The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 440, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  61.61  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 370, wc = 0.45, materials = 0.7/0.3, curing = Heat curing. ', 38.63), ('The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. ', 54.97), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 58.03)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  61.95  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 420, wc = 0.45, materials = 0.5/0.5, curing = Heat curing. ', 54.97), ('The formulation is Powderkg = 450, wc = 0.6, materials = 0.7/0.3, curing = Heat curing. ', 40.12), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.', 55.12)]
# final response The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  64.6  MPa.
# Data for experiment 8 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_8_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435813.csv.
#
# ---
# Starting experiment 9...
# ---
#
# ---
# Starting iteration 1 at temp 0.7...
# [('The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing', 55.0), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Heat curing', 55.0), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = Heat curing', 55.0)]
# final response The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing
# Model Response:  The formulation is Powderkg = 440, wc = 0.45, materials = 0.6/0.4, curing = Heat curing
# The suggested formulation achieved a strength of  57.27  MPa.
#
# ---
# Starting iteration 2 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing', 58.5), ('The formulation is Powderkg = 430, wc = 0.5, materials = 0.5/0.5, curing = Heat curing', 55.12), ('The formulation is Powderkg = 420, wc = 0.6, materials = 0.6/0.4, curing = Ambient curing', 45.12)]
# final response The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing
# Model Response:  The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing
# The suggested formulation achieved a strength of  38.63  MPa.
#
# ---
# Starting iteration 3 at temp 0.7...
# [('The formulation is Powderkg = 410, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 55.12), ('The formulation is Powderkg = 420, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.', 55.12), ('The formulation is Powderkg = 450, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.', 45.12)]
# final response The formulation is Powderkg = 410, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 410, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  58.24  MPa.
#
# ---
# Starting iteration 4 at temp 0.7...
# [('The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 55.12), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.5/0.5, curing = Ambient curing.', 45.12), ('The formulation is Powderkg = 380, wc = 0.55, materials = 0.7/0.3, curing = Heat curing.', 45.12)]
# final response The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  60.68  MPa.
#
# ---
# Starting iteration 5 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing.', 45.12), ('The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.', 55.82), ('The formulation is Powderkg = 420, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.', 55.12)]
# final response The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 450, wc = 0.55, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  54.38  MPa.
#
# ---
# Starting iteration 6 at temp 0.7...
# [('The formulation is Powderkg = 420, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 55.12), ('The formulation is Powderkg = 430, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing.', 45.12), ('The formulation is Powderkg = 400, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.', 55.12)]
# final response The formulation is Powderkg = 420, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 420, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  40.41  MPa.
#
# ---
# Starting iteration 7 at temp 0.7...
# [('The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.', 59.12), ('The formulation is Powderkg = 410, wc = 0.5, materials = 0.7/0.3, curing = Ambient curing.', 35.12), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 58.24)]
# final response The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 430, wc = 0.5, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  61.95  MPa.
#
# ---
# Starting iteration 8 at temp 0.7...
# [('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Heat curing.', 38.63), ('The formulation is Powderkg = 380, wc = 0.5, materials = 0.5/0.5, curing = Ambient curing.', 45.12), ('The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.', 62.12)]
# final response The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 410, wc = 0.55, materials = 0.6/0.4, curing = Heat curing.
# The suggested formulation achieved a strength of  58.06  MPa.
#
# ---
# Starting iteration 9 at temp 0.7...
# [('The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.', 45.12), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.6/0.4, curing = Ambient curing.', 45.12), ('The formulation is Powderkg = 380, wc = 0.6, materials = 0.5/0.5, curing = Heat curing.', 45.12)]
# final response The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 390, wc = 0.5, materials = 0.7/0.3, curing = Heat curing.
# The suggested formulation achieved a strength of  43.03  MPa.
#
# ---
# Starting iteration 10 at temp 0.7...
# [('The formulation is Powderkg = 370, wc = 0.45, materials = 0.6/0.4, curing = Heat curing.', 57.27), ('The formulation is Powderkg = 450, wc = 0.45, materials = 0.7/0.3, curing = Ambient curing.', 38.63), ('The formulation is Powderkg = 400, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.', 58.24)]
# final response The formulation is Powderkg = 400, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# Model Response:  The formulation is Powderkg = 400, wc = 0.45, materials = 0.5/0.5, curing = Heat curing.
# The suggested formulation achieved a strength of  58.98  MPa.
# Data for experiment 9 and temp 0.7 successfully saved to Results/ID/gpt-3.5-turbo_Generic_prompt_experiment_9_temp_0.7_target_99_%_Dev_Budget_10_recursive_1_1696435870.csv.

# %% [markdown]
# ##  Run Baseline Methods (BO,RF, RP) 30 times

# %%
# %run utils/Baselines.ipynb
